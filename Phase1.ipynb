# %% [markdown]
# - Sum of two integers
# - Print the message along with values and sum
# 	Ex - The sum of 45 & 12  = 57
# - Accept two integers from user and print the sum
# 	Ex - The sum of 45 & 12 = 57
# - Accept the User's name, age and print in following manner
# 	Ex - Hello Shery, you are 12 years old.
# - Solve Increment & decrement operator questions on
# 	https://javaconceptoftheday.com/quiz-on-increment-and-decrement-operators/
# - Accept two numbers from user and swap their values
#                 Part 2 - Swap without using third variable

# %%
print(1+10)
# Out:
# 11
